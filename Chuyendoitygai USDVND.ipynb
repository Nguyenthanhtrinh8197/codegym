# %%
n = input('Nhap USD can doi:')
m = input('Ty gia USD/VND:')
print(f'Voi {n} USD duoc quy doi theo ty gia thi so tien theo VND la: {int(m)*int(n)} VND')
# Out:
# Nhap USD can doi:100
# Ty gia USD/VND:23000
# Voi 100 USD duoc quy doi theo ty gia thi so tien theo VND la: 2300000 VND
